# %% [markdown]
# Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# A1. We use the Exception class while creating a Custom Exception to:

# %% [markdown]
# Improve readability of your code.

# %% [markdown]
# Enhance reusability of features.

# %% [markdown]
# Provide custom messages to users for specific use cases.

# %% [markdown]
# Allow the programmer to be specific in their catch clauses, and only catch the exceptions they care about and know what to do with.

# %% [markdown]
# Carry information about the error that caused the exception

# %% [markdown]
# Q2. Write a python program to print Python Exception Hierarchy

# %%
import inspect
def treeClass(cls, ind = 0):
    print ('-' * ind, cls.__name__)
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
    print("Hierarchy for Built-in exceptions is : ")
inspect.getclasstree(inspect.getmro(BaseException))
treeClass(BaseException)
# Out:
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# Hierarchy for Built-in exceptions is :
# --------- MultipartConversionError
# Hierarchy for Built-in exceptions is :
# Hierarchy for Built-in exceptions is :
# ------ StopAsyncIteration
# Hierarchy for Built-in exceptions is :
# ------ StopIteration
# Hierarchy for Built-in exceptions is :
# ------ ImportError
# --------- ModuleNotFoundError
# Hierarchy for Built-in exceptions is :
# --------- ZipImportError
# Hierarchy for Built-in exceptions is :
# Hierarchy for Built-in exceptions is :
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# Hierarchy for Built-in exceptions is :
# ------------ ConnectionAbortedError
# Hierarchy for Built-in exceptions is :
# ------------ ConnectionRefusedError
# Hierarchy for Built-in exceptions is :
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# Hierarchy for Built-in exceptions is :
# ...

# %% [markdown]
# Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# The ArithmeticError class is the base class for all errors associated with arithmetic operations in Python. It is inherited by other classes such as ZeroDivisionError, OverflowError, and FloatingPointError.

# %% [markdown]
# ZeroDivisionError = ZeroDivisionError occurs when we perform division operation of any intiger with 0 (zero).and print the message of ZeroDivisionError . for example :

# %%
a=10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=10/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# OverflowError: This error occurs when we try to perform an operation whose result is in a number which is too large to be represented . For example, for example :

# %%
a=999999999999999999999999999999999999999999
b=999999999999999999999999999999999999999999
c=a*b

# %% [markdown]
# Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# A4. The LookupError exception in Python forms the base class for all exceptions that are used to raised when an index or a key is not found for a sequence or dictionary respectively.

# %%
fruits = {'apple': 2, 'banana': 4, 'orange': 1}
try:
    fruit = fruits['mango']
    print(fruit)
except LookupError:
    print("Fruit does not exist.")
# Out:
# Fruit does not exist.

# %% [markdown]
# IndexError: This exception is raised when an index is out of range for a list, tuple, or other sequence types.
# KeyError: This exception is raised when a key is not found in a dictionary.

# %%
# KEY ERROR EXAMPLE
a={'NAME' :'apoorv'}
a['class']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 # KEY ERROR EXAMPLE
#       2 a={'NAME' :'apoorv'}
# ----> 3 a['class']
#
# KeyError: 'class'

# %%
l=[1,2,3,4]
l[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 2
#       1 l=[1,2,3,4]
# ----> 2 l[9]
#
# IndexError: list index out of range

# %% [markdown]
# Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# A5. ImportError is raised when an import statement has trouble successfully importing the specified module. Typically, such a problem is due to an invalid or incorrect path, which will raise a ModuleNotFoundError.
# ModuleNotFoundError is a kind of ImportError. It’s raised specifically when the module cannot be found at all

# %% [markdown]
# EXAMPLE OF IMPORT ERROR

# %%
from math import soo
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from math import soo
#
# ImportError: cannot import name 'soo' from 'math' (/opt/conda/lib/python3.10/lib-dynload/math.cpython-310-x86_64-linux-gnu.so)

# %% [markdown]
# EXAMPLE OF MODULE NOT FOUND ERROR

# %%
import mathing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import mathing
#
# ModuleNotFoundError: No module named 'mathing'

# %% [markdown]
# Q6. List down some best practices for exception handling in python.

# %% [markdown]
# #  use always a specific exception

# %%
try :
    10/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %% [markdown]
# # always try to log your error with a proper message

# %%
 
import logging
logging. basicConfig(filename="error.log",level=logging.ERROR)
try :
    10/0
except ZeroDivisionError as e:
    logging.error(" i am tyring to handle zerodivisionerror {}".format(e))

# %% [markdown]
# # always avoid to write a multiple exception handling

# %%
# THIS SHOULD NOT BE DONE WE SHOULD NOT USE MULTIPLE EXCEPTION LIKE GIVEN BELOW BECAUSE ONLY ONE EXCEPTION WILL HANDLE 

import logging

logging. basicConfig(filename="error.log",level=logging.ERROR)
try :
    10/0
    
except ModuleNotFoundError as m:
    logging.error('i am trying to handle ModuleNotFoundError {} '.format(m))
    
except ValueError as v:
    logging.error('i am trying to handle ValueError')

except ImportError as i:
    logging.error('i am trying to handle Import Error')

except ZeroDivisionError as e:
    logging.error(" i am tyring to handle zerodivisionerror {}".format(e))
